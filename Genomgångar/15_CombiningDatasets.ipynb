# %% [markdown]
# # Kombinera dataset
#
# Pandas har flera sätt att kombinera dataset
#
# - Concat: kombinera DataFrames
# - Join: kombinera på en rad eller kolumn
# - Merge: Kombinera liknande? rader och kolumner

# %%
import pandas as pd
from helpers import sample_df, hdisplay, nowrap_display

# %% [markdown]
# ## Concatenate

# %%
left = sample_df("A0", "D3", prefix="L_")
right = sample_df("A0", "D3", prefix="R_")

hdisplay([left, right], ["left", "right"])
# Out:
# <style type="text/css">
# #T_faa83 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_faa83" style='display:inline; margin-right: 50px;'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faa83_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_faa83_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_faa83_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_faa83_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faa83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faa83_row0_col0" class="data row0 col0" >L_A0</td>
#       <td id="T_faa83_row0_col1" class="data row0 col1" >L_B0</td>
#       <td id="T_faa83_row0_col2" class="data row0 col2" >L_C0</td>
#       <td id="T_faa83_row0_col3" class="data row0 col3" >L_D0</td>
#     </tr>
#     <tr>
#       <th id="T_faa83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_faa83_row1_col0" class="data row1 col0" >L_A1</td>
#       <td id="T_faa83_row1_col1" class="data row1 col1" >L_B1</td>
#       <td id="T_faa83_row1_col2" class="data row1 col2" >L_C1</td>
#       <td id="T_faa83_row1_col3" class="data row1 col3" >L_D1</td>
#     </tr>
#     <tr>
#       <th id="T_faa83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_faa83_row2_col0" class="data row2 col0" >L_A2</td>
#       <td id="T_faa83_row2_col1" class="data row2 col1" >L_B2</td>
#       <td id="T_faa83_row2_col2" class="data row2 col2" >L_C2</td>
#       <td id="T_faa83_row2_col3" class="data row2 col3" >L_D2</td>
#     </tr>
#     <tr>
#       <th id="T_faa83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_faa83_row3_col0" class="data row3 col0" >L_A3</td>
#       <td id="T_faa83_row3_col1" class="data row3 col1" >L_B3</td>
#       <td id="T_faa83_row3_col2" class="data row3 col2" >L_C3</td>
#       <td id="T_faa83_row3_col3" class="data row3 col3" >L_D3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_51f31 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_51f31" style='display:inline; margin-right: 50px;'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f31_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_51f31_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_51f31_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_51f31_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51f31_row0_col0" class="data row0 col0" >R_A0</td>
#       <td id="T_51f31_row0_col1" class="data row0 col1" >R_B0</td>
#       <td id="T_51f31_row0_col2" class="data row0 col2" >R_C0</td>
#       <td id="T_51f31_row0_col3" class="data row0 col3" >R_D0</td>
#     </tr>
#     <tr>
#       <th id="T_51f31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51f31_row1_col0" class="data row1 col0" >R_A1</td>
#       <td id="T_51f31_row1_col1" class="data row1 col1" >R_B1</td>
#       <td id="T_51f31_row1_col2" class="data row1 col2" >R_C1</td>
#       <td id="T_51f31_row1_col3" class="data row1 col3" >R_D1</td>
#     </tr>
#     <tr>
#       <th id="T_51f31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51f31_row2_col0" class="data row2 col0" >R_A2</td>
#       <td id="T_51f31_row2_col1" class="data row2 col1" >R_B2</td>
#       <td id="T_51f31_row2_col2" class="data row2 col2" >R_C2</td>
#       <td id="T_51f31_row2_col3" class="data row2 col3" >R_D2</td>
#     </tr>
#     <tr>
#       <th id="T_51f31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51f31_row3_col0" class="data row3 col0" >R_A3</td>
#       <td id="T_51f31_row3_col1" class="data row3 col1" >R_B3</td>
#       <td id="T_51f31_row3_col2" class="data row3 col2" >R_C3</td>
#       <td id="T_51f31_row3_col3" class="data row3 col3" >R_D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.concat([left, right], axis="columns") # default axis=index
# Out:
#       A     B     C     D     A     B     C     D
# 0  L_A0  L_B0  L_C0  L_D0  R_A0  R_B0  R_C0  R_D0
# 1  L_A1  L_B1  L_C1  L_D1  R_A1  R_B1  R_C1  R_D1
# 2  L_A2  L_B2  L_C2  L_D2  R_A2  R_B2  R_C2  R_D2
# 3  L_A3  L_B3  L_C3  L_D3  R_A3  R_B3  R_C3  R_D3

# %%
pd.concat([left, right]).reset_index(drop=True)
pd.concat([left, right]).set_index("C")
pd.concat([left, right], axis="columns", keys=["left", "right"])
pd.concat([left, right], ignore_index=True)
# Out:
#       A     B     C     D
# 0  L_A0  L_B0  L_C0  L_D0
# 1  L_A1  L_B1  L_C1  L_D1
# 2  L_A2  L_B2  L_C2  L_D2
# 3  L_A3  L_B3  L_C3  L_D3
# 4  R_A0  R_B0  R_C0  R_D0
# 5  R_A1  R_B1  R_C1  R_D1
# 6  R_A2  R_B2  R_C2  R_D2
# 7  R_A3  R_B3  R_C3  R_D3

# %%
left = sample_df("A0", "D3", prefix="L_")
right = sample_df("C2", "F5", prefix="R_")

hdisplay([left, right], ["left", "right"])
# Out:
# <style type="text/css">
# #T_b1274 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_b1274" style='display:inline; margin-right: 50px;'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1274_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b1274_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b1274_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b1274_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1274_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1274_row0_col0" class="data row0 col0" >L_A0</td>
#       <td id="T_b1274_row0_col1" class="data row0 col1" >L_B0</td>
#       <td id="T_b1274_row0_col2" class="data row0 col2" >L_C0</td>
#       <td id="T_b1274_row0_col3" class="data row0 col3" >L_D0</td>
#     </tr>
#     <tr>
#       <th id="T_b1274_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1274_row1_col0" class="data row1 col0" >L_A1</td>
#       <td id="T_b1274_row1_col1" class="data row1 col1" >L_B1</td>
#       <td id="T_b1274_row1_col2" class="data row1 col2" >L_C1</td>
#       <td id="T_b1274_row1_col3" class="data row1 col3" >L_D1</td>
#     </tr>
#     <tr>
#       <th id="T_b1274_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1274_row2_col0" class="data row2 col0" >L_A2</td>
#       <td id="T_b1274_row2_col1" class="data row2 col1" >L_B2</td>
#       <td id="T_b1274_row2_col2" class="data row2 col2" >L_C2</td>
#       <td id="T_b1274_row2_col3" class="data row2 col3" >L_D2</td>
#     </tr>
#     <tr>
#       <th id="T_b1274_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1274_row3_col0" class="data row3 col0" >L_A3</td>
#       <td id="T_b1274_row3_col1" class="data row3 col1" >L_B3</td>
#       <td id="T_b1274_row3_col2" class="data row3 col2" >L_C3</td>
#       <td id="T_b1274_row3_col3" class="data row3 col3" >L_D3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_df0a7 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_df0a7" style='display:inline; margin-right: 50px;'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df0a7_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_df0a7_level0_col1" class="col_heading level0 col1" >D</th>
#       <th id="T_df0a7_level0_col2" class="col_heading level0 col2" >E</th>
#       <th id="T_df0a7_level0_col3" class="col_heading level0 col3" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df0a7_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_df0a7_row0_col0" class="data row0 col0" >R_C2</td>
#       <td id="T_df0a7_row0_col1" class="data row0 col1" >R_D2</td>
#       <td id="T_df0a7_row0_col2" class="data row0 col2" >R_E2</td>
#       <td id="T_df0a7_row0_col3" class="data row0 col3" >R_F2</td>
#     </tr>
#     <tr>
#       <th id="T_df0a7_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_df0a7_row1_col0" class="data row1 col0" >R_C3</td>
#       <td id="T_df0a7_row1_col1" class="data row1 col1" >R_D3</td>
#       <td id="T_df0a7_row1_col2" class="data row1 col2" >R_E3</td>
#       <td id="T_df0a7_row1_col3" class="data row1 col3" >R_F3</td>
#     </tr>
#     <tr>
#       <th id="T_df0a7_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_df0a7_row2_col0" class="data row2 col0" >R_C4</td>
#       <td id="T_df0a7_row2_col1" class="data row2 col1" >R_D4</td>
#       <td id="T_df0a7_row2_col2" class="data row2 col2" >R_E4</td>
#       <td id="T_df0a7_row2_col3" class="data row2 col3" >R_F4</td>
#     </tr>
#     <tr>
#       <th id="T_df0a7_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_df0a7_row3_col0" class="data row3 col0" >R_C5</td>
#       <td id="T_df0a7_row3_col1" class="data row3 col1" >R_D5</td>
#       <td id="T_df0a7_row3_col2" class="data row3 col2" >R_E5</td>
#       <td id="T_df0a7_row3_col3" class="data row3 col3" >R_F5</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.concat([left, right], axis="columns")
# Out:
#       A     B     C     D     C     D     E     F
# 0  L_A0  L_B0  L_C0  L_D0   NaN   NaN   NaN   NaN
# 1  L_A1  L_B1  L_C1  L_D1   NaN   NaN   NaN   NaN
# 2  L_A2  L_B2  L_C2  L_D2  R_C2  R_D2  R_E2  R_F2
# 3  L_A3  L_B3  L_C3  L_D3  R_C3  R_D3  R_E3  R_F3
# 4   NaN   NaN   NaN   NaN  R_C4  R_D4  R_E4  R_F4
# 5   NaN   NaN   NaN   NaN  R_C5  R_D5  R_E5  R_F5

# %%
df = pd.concat([left, right], keys=["left", "right"])
df.loc['left']
# Out:
#       A     B     C     D    E    F
# 0  L_A0  L_B0  L_C0  L_D0  NaN  NaN
# 1  L_A1  L_B1  L_C1  L_D1  NaN  NaN
# 2  L_A2  L_B2  L_C2  L_D2  NaN  NaN
# 3  L_A3  L_B3  L_C3  L_D3  NaN  NaN

# %% [markdown]
# ## Join
# - Tänk på att Vänster/Höger är en grej i syntax. (inte bara nu i våra tillfälliga variabelnamn)

# %%
left = sample_df("A0", "D3", prefix="L_").add_suffix("_left")
right = sample_df("C2", "F5", prefix="R_").add_suffix("_right")

hdisplay([left, right], ["left", "right"])
# Out:
# <style type="text/css">
# #T_a0786 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_a0786" style='display:inline; margin-right: 50px;'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0786_level0_col0" class="col_heading level0 col0" >A_left</th>
#       <th id="T_a0786_level0_col1" class="col_heading level0 col1" >B_left</th>
#       <th id="T_a0786_level0_col2" class="col_heading level0 col2" >C_left</th>
#       <th id="T_a0786_level0_col3" class="col_heading level0 col3" >D_left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0786_row0_col0" class="data row0 col0" >L_A0</td>
#       <td id="T_a0786_row0_col1" class="data row0 col1" >L_B0</td>
#       <td id="T_a0786_row0_col2" class="data row0 col2" >L_C0</td>
#       <td id="T_a0786_row0_col3" class="data row0 col3" >L_D0</td>
#     </tr>
#     <tr>
#       <th id="T_a0786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0786_row1_col0" class="data row1 col0" >L_A1</td>
#       <td id="T_a0786_row1_col1" class="data row1 col1" >L_B1</td>
#       <td id="T_a0786_row1_col2" class="data row1 col2" >L_C1</td>
#       <td id="T_a0786_row1_col3" class="data row1 col3" >L_D1</td>
#     </tr>
#     <tr>
#       <th id="T_a0786_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0786_row2_col0" class="data row2 col0" >L_A2</td>
#       <td id="T_a0786_row2_col1" class="data row2 col1" >L_B2</td>
#       <td id="T_a0786_row2_col2" class="data row2 col2" >L_C2</td>
#       <td id="T_a0786_row2_col3" class="data row2 col3" >L_D2</td>
#     </tr>
#     <tr>
#       <th id="T_a0786_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0786_row3_col0" class="data row3 col0" >L_A3</td>
#       <td id="T_a0786_row3_col1" class="data row3 col1" >L_B3</td>
#       <td id="T_a0786_row3_col2" class="data row3 col2" >L_C3</td>
#       <td id="T_a0786_row3_col3" class="data row3 col3" >L_D3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f296c th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_f296c" style='display:inline; margin-right: 50px;'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f296c_level0_col0" class="col_heading level0 col0" >C_right</th>
#       <th id="T_f296c_level0_col1" class="col_heading level0 col1" >D_right</th>
#       <th id="T_f296c_level0_col2" class="col_heading level0 col2" >E_right</th>
#       <th id="T_f296c_level0_col3" class="col_heading level0 col3" >F_right</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f296c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_f296c_row0_col0" class="data row0 col0" >R_C2</td>
#       <td id="T_f296c_row0_col1" class="data row0 col1" >R_D2</td>
#       <td id="T_f296c_row0_col2" class="data row0 col2" >R_E2</td>
#       <td id="T_f296c_row0_col3" class="data row0 col3" >R_F2</td>
#     </tr>
#     <tr>
#       <th id="T_f296c_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_f296c_row1_col0" class="data row1 col0" >R_C3</td>
#       <td id="T_f296c_row1_col1" class="data row1 col1" >R_D3</td>
#       <td id="T_f296c_row1_col2" class="data row1 col2" >R_E3</td>
#       <td id="T_f296c_row1_col3" class="data row1 col3" >R_F3</td>
#     </tr>
#     <tr>
#       <th id="T_f296c_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_f296c_row2_col0" class="data row2 col0" >R_C4</td>
#       <td id="T_f296c_row2_col1" class="data row2 col1" >R_D4</td>
#       <td id="T_f296c_row2_col2" class="data row2 col2" >R_E4</td>
#       <td id="T_f296c_row2_col3" class="data row2 col3" >R_F4</td>
#     </tr>
#     <tr>
#       <th id="T_f296c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_f296c_row3_col0" class="data row3 col0" >R_C5</td>
#       <td id="T_f296c_row3_col1" class="data row3 col1" >R_D5</td>
#       <td id="T_f296c_row3_col2" class="data row3 col2" >R_E5</td>
#       <td id="T_f296c_row3_col3" class="data row3 col3" >R_F5</td>
#     </tr>
#   </tbody>
# </table>

# %%
left.join(right, how="right") # finns även inner(tar bara med non-NaN r/k), outer(tar med allt), cross(tar med alla kombos len(r)*len(l)) (left default)
# Out:
#   A_left B_left C_left D_left C_right D_right E_right F_right
# 2   L_A2   L_B2   L_C2   L_D2    R_C2    R_D2    R_E2    R_F2
# 3   L_A3   L_B3   L_C3   L_D3    R_C3    R_D3    R_E3    R_F3
# 4    NaN    NaN    NaN    NaN    R_C4    R_D4    R_E4    R_F4
# 5    NaN    NaN    NaN    NaN    R_C5    R_D5    R_E5    R_F5

# %% [markdown]
# ## Merge
# - Lite som join, men mer valbart om hur dataframsen ska sättas ihop
#
# - how= finns här också men här är istället default "inner"
#
# - Lätt att blandas ihop med SQL syntax där SQLs merge heter .join

# %%
left = sample_df("A0", "D3")
left.loc[:, "F"] = ["F8", "F9", "F10", "F11"]
right = sample_df("F10", "J13")
hdisplay([left, right], ["left", "right"])
# Out:
# <style type="text/css">
# #T_d4bd2 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_d4bd2" style='display:inline; margin-right: 50px;'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4bd2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d4bd2_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_d4bd2_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_d4bd2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_d4bd2_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4bd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4bd2_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_d4bd2_row0_col1" class="data row0 col1" >B0</td>
#       <td id="T_d4bd2_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_d4bd2_row0_col3" class="data row0 col3" >D0</td>
#       <td id="T_d4bd2_row0_col4" class="data row0 col4" >F8</td>
#     </tr>
#     <tr>
#       <th id="T_d4bd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4bd2_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_d4bd2_row1_col1" class="data row1 col1" >B1</td>
#       <td id="T_d4bd2_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_d4bd2_row1_col3" class="data row1 col3" >D1</td>
#       <td id="T_d4bd2_row1_col4" class="data row1 col4" >F9</td>
#     </tr>
#     <tr>
#       <th id="T_d4bd2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4bd2_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_d4bd2_row2_col1" class="data row2 col1" >B2</td>
#       <td id="T_d4bd2_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_d4bd2_row2_col3" class="data row2 col3" >D2</td>
#       <td id="T_d4bd2_row2_col4" class="data row2 col4" >F10</td>
#     </tr>
#     <tr>
#       <th id="T_d4bd2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4bd2_row3_col0" class="data row3 col0" >A3</td>
#       <td id="T_d4bd2_row3_col1" class="data row3 col1" >B3</td>
#       <td id="T_d4bd2_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_d4bd2_row3_col3" class="data row3 col3" >D3</td>
#       <td id="T_d4bd2_row3_col4" class="data row3 col4" >F11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ccd01 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_ccd01" style='display:inline; margin-right: 50px;'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccd01_level0_col0" class="col_heading level0 col0" >F</th>
#       <th id="T_ccd01_level0_col1" class="col_heading level0 col1" >G</th>
#       <th id="T_ccd01_level0_col2" class="col_heading level0 col2" >H</th>
#       <th id="T_ccd01_level0_col3" class="col_heading level0 col3" >I</th>
#       <th id="T_ccd01_level0_col4" class="col_heading level0 col4" >J</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccd01_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_ccd01_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_ccd01_row0_col1" class="data row0 col1" >G10</td>
#       <td id="T_ccd01_row0_col2" class="data row0 col2" >H10</td>
#       <td id="T_ccd01_row0_col3" class="data row0 col3" >I10</td>
#       <td id="T_ccd01_row0_col4" class="data row0 col4" >J10</td>
#     </tr>
#     <tr>
#       <th id="T_ccd01_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_ccd01_row1_col0" class="data row1 col0" >F11</td>
#       <td id="T_ccd01_row1_col1" class="data row1 col1" >G11</td>
#       <td id="T_ccd01_row1_col2" class="data row1 col2" >H11</td>
#       <td id="T_ccd01_row1_col3" class="data row1 col3" >I11</td>
#       <td id="T_ccd01_row1_col4" class="data row1 col4" >J11</td>
#     </tr>
#     <tr>
#       <th id="T_ccd01_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_ccd01_row2_col0" class="data row2 col0" >F12</td>
#       <td id="T_ccd01_row2_col1" class="data row2 col1" >G12</td>
#       <td id="T_ccd01_row2_col2" class="data row2 col2" >H12</td>
#       <td id="T_ccd01_row2_col3" class="data row2 col3" >I12</td>
#       <td id="T_ccd01_row2_col4" class="data row2 col4" >J12</td>
#     </tr>
#     <tr>
#       <th id="T_ccd01_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_ccd01_row3_col0" class="data row3 col0" >F13</td>
#       <td id="T_ccd01_row3_col1" class="data row3 col1" >G13</td>
#       <td id="T_ccd01_row3_col2" class="data row3 col2" >H13</td>
#       <td id="T_ccd01_row3_col3" class="data row3 col3" >I13</td>
#       <td id="T_ccd01_row3_col4" class="data row3 col4" >J13</td>
#     </tr>
#   </tbody>
# </table>

# %%
left.merge(right, how="outer")
# Out:
#      A    B    C    D    F    G    H    I    J
# 0   A0   B0   C0   D0   F8  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1   F9  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  F10  G10  H10  I10  J10
# 3   A3   B3   C3   D3  F11  G11  H11  I11  J11
# 4  NaN  NaN  NaN  NaN  F12  G12  H12  I12  J12
# 5  NaN  NaN  NaN  NaN  F13  G13  H13  I13  J13

# %% [markdown]
# ## Lite riktiga exempel

# %%
employees = pd.read_json("../Data/employees.json")
departments = pd.read_json("../Data/departments.json")
display(employees)
display(departments)
# Out:
#   first_name last_name              job_title  salary       department
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources
#    department_name  department_head       location  office_number   budget
# 0            Sales   Sarah Williams       New York            101  1000000
# 1  Human Resources      David Brown        Chicago            202   800000
# 2               IT  Michael Johnson  San Francisco            303  1200000

# %%
df = employees.merge(departments, left_on="department", right_on="department_name", how="left", sort=True).drop(columns="department_name")
nowrap_display(df)
# Out:
# <style type="text/css">
# #T_7e07b th {
#   text-align: left;
# }
# #T_7e07b_row0_col0, #T_7e07b_row0_col1, #T_7e07b_row0_col2, #T_7e07b_row0_col3, #T_7e07b_row0_col4, #T_7e07b_row0_col5, #T_7e07b_row0_col6, #T_7e07b_row0_col7, #T_7e07b_row0_col8, #T_7e07b_row1_col0, #T_7e07b_row1_col1, #T_7e07b_row1_col2, #T_7e07b_row1_col3, #T_7e07b_row1_col4, #T_7e07b_row1_col5, #T_7e07b_row1_col6, #T_7e07b_row1_col7, #T_7e07b_row1_col8, #T_7e07b_row2_col0, #T_7e07b_row2_col1, #T_7e07b_row2_col2, #T_7e07b_row2_col3, #T_7e07b_row2_col4, #T_7e07b_row2_col5, #T_7e07b_row2_col6, #T_7e07b_row2_col7, #T_7e07b_row2_col8, #T_7e07b_row3_col0, #T_7e07b_row3_col1, #T_7e07b_row3_col2, #T_7e07b_row3_col3, #T_7e07b_row3_col4, #T_7e07b_row3_col5, #T_7e07b_row3_col6, #T_7e07b_row3_col7, #T_7e07b_row3_col8, #T_7e07b_row4_col0, #T_7e07b_row4_col1, #T_7e07b_row4_col2, #T_7e07b_row4_col3, #T_7e07b_row4_col4, #T_7e07b_row4_col5, #T_7e07b_row4_col6, #T_7e07b_row4_col7, #T_7e07b_row4_col8, #T_7e07b_row5_col0, #T_7e07b_row5_col1, #T_7e07b_row5_col2, #T_7e07b_row5_col3, #T_7e07b_row5_col4, #T_7e07b_row5_col5, #T_7e07b_row5_col6, #T_7e07b_row5_col7, #T_7e07b_row5_col8, #T_7e07b_row6_col0, #T_7e07b_row6_col1, #T_7e07b_row6_col2, #T_7e07b_row6_col3, #T_7e07b_row6_col4, #T_7e07b_row6_col5, #T_7e07b_row6_col6, #T_7e07b_row6_col7, #T_7e07b_row6_col8, #T_7e07b_row7_col0, #T_7e07b_row7_col1, #T_7e07b_row7_col2, #T_7e07b_row7_col3, #T_7e07b_row7_col4, #T_7e07b_row7_col5, #T_7e07b_row7_col6, #T_7e07b_row7_col7, #T_7e07b_row7_col8, #T_7e07b_row8_col0, #T_7e07b_row8_col1, #T_7e07b_row8_col2, #T_7e07b_row8_col3, #T_7e07b_row8_col4, #T_7e07b_row8_col5, #T_7e07b_row8_col6, #T_7e07b_row8_col7, #T_7e07b_row8_col8, #T_7e07b_row9_col0, #T_7e07b_row9_col1, #T_7e07b_row9_col2, #T_7e07b_row9_col3, #T_7e07b_row9_col4, #T_7e07b_row9_col5, #T_7e07b_row9_col6, #T_7e07b_row9_col7, #T_7e07b_row9_col8 {
#   font-size: 12pt;
#   text-align: left;
#   white-space: nowrap;
# }
# </style>
# <table id="T_7e07b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e07b_level0_col0" class="col_heading level0 col0" >first_name</th>
#       <th id="T_7e07b_level0_col1" class="col_heading level0 col1" >last_name</th>
#       <th id="T_7e07b_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_7e07b_level0_col3" class="col_heading level0 col3" >salary</th>
#       <th id="T_7e07b_level0_col4" class="col_heading level0 col4" >department</th>
#       <th id="T_7e07b_level0_col5" class="col_heading level0 col5" >department_head</th>
#       <th id="T_7e07b_level0_col6" class="col_heading level0 col6" >location</th>
#       <th id="T_7e07b_level0_col7" class="col_heading level0 col7" >office_number</th>
#       <th id="T_7e07b_level0_col8" class="col_heading level0 col8" >budget</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e07b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e07b_row0_col0" class="data row0 col0" >Jane</td>
#       <td id="T_7e07b_row0_col1" class="data row0 col1" >Smith</td>
#       <td id="T_7e07b_row0_col2" class="data row0 col2" >HR Coordinator</td>
#       <td id="T_7e07b_row0_col3" class="data row0 col3" >60000</td>
#       <td id="T_7e07b_row0_col4" class="data row0 col4" >Human Resources</td>
#       <td id="T_7e07b_row0_col5" class="data row0 col5" >David Brown</td>
#       <td id="T_7e07b_row0_col6" class="data row0 col6" >Chicago</td>
#       <td id="T_7e07b_row0_col7" class="data row0 col7" >202</td>
#       <td id="T_7e07b_row0_col8" class="data row0 col8" >800000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e07b_row1_col0" class="data row1 col0" >David</td>
#       <td id="T_7e07b_row1_col1" class="data row1 col1" >Brown</td>
#       <td id="T_7e07b_row1_col2" class="data row1 col2" >HR Manager</td>
#       <td id="T_7e07b_row1_col3" class="data row1 col3" >90000</td>
#       <td id="T_7e07b_row1_col4" class="data row1 col4" >Human Resources</td>
#       <td id="T_7e07b_row1_col5" class="data row1 col5" >David Brown</td>
#       <td id="T_7e07b_row1_col6" class="data row1 col6" >Chicago</td>
#       <td id="T_7e07b_row1_col7" class="data row1 col7" >202</td>
#       <td id="T_7e07b_row1_col8" class="data row1 col8" >800000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e07b_row2_col0" class="data row2 col0" >Sophia</td>
#       <td id="T_7e07b_row2_col1" class="data row2 col1" >Taylor</td>
#       <td id="T_7e07b_row2_col2" class="data row2 col2" >HR Assistant</td>
#       <td id="T_7e07b_row2_col3" class="data row2 col3" >50000</td>
#       <td id="T_7e07b_row2_col4" class="data row2 col4" >Human Resources</td>
#       <td id="T_7e07b_row2_col5" class="data row2 col5" >David Brown</td>
#       <td id="T_7e07b_row2_col6" class="data row2 col6" >Chicago</td>
#       <td id="T_7e07b_row2_col7" class="data row2 col7" >202</td>
#       <td id="T_7e07b_row2_col8" class="data row2 col8" >800000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e07b_row3_col0" class="data row3 col0" >Michael</td>
#       <td id="T_7e07b_row3_col1" class="data row3 col1" >Johnson</td>
#       <td id="T_7e07b_row3_col2" class="data row3 col2" >Software Engineer</td>
#       <td id="T_7e07b_row3_col3" class="data row3 col3" >110000</td>
#       <td id="T_7e07b_row3_col4" class="data row3 col4" >IT</td>
#       <td id="T_7e07b_row3_col5" class="data row3 col5" >Michael Johnson</td>
#       <td id="T_7e07b_row3_col6" class="data row3 col6" >San Francisco</td>
#       <td id="T_7e07b_row3_col7" class="data row3 col7" >303</td>
#       <td id="T_7e07b_row3_col8" class="data row3 col8" >1200000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e07b_row4_col0" class="data row4 col0" >Emily</td>
#       <td id="T_7e07b_row4_col1" class="data row4 col1" >Davis</td>
#       <td id="T_7e07b_row4_col2" class="data row4 col2" >IT Support Specialist</td>
#       <td id="T_7e07b_row4_col3" class="data row4 col3" >55000</td>
#       <td id="T_7e07b_row4_col4" class="data row4 col4" >IT</td>
#       <td id="T_7e07b_row4_col5" class="data row4 col5" >Michael Johnson</td>
#       <td id="T_7e07b_row4_col6" class="data row4 col6" >San Francisco</td>
#       <td id="T_7e07b_row4_col7" class="data row4 col7" >303</td>
#       <td id="T_7e07b_row4_col8" class="data row4 col8" >1200000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e07b_row5_col0" class="data row5 col0" >John</td>
#       <td id="T_7e07b_row5_col1" class="data row5 col1" >Doe</td>
#       <td id="T_7e07b_row5_col2" class="data row5 col2" >Sales Director</td>
#       <td id="T_7e07b_row5_col3" class="data row5 col3" >120000</td>
#       <td id="T_7e07b_row5_col4" class="data row5 col4" >Sales</td>
#       <td id="T_7e07b_row5_col5" class="data row5 col5" >Sarah Williams</td>
#       <td id="T_7e07b_row5_col6" class="data row5 col6" >New York</td>
#       <td id="T_7e07b_row5_col7" class="data row5 col7" >101</td>
#       <td id="T_7e07b_row5_col8" class="data row5 col8" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e07b_row6_col0" class="data row6 col0" >Sarah</td>
#       <td id="T_7e07b_row6_col1" class="data row6 col1" >Williams</td>
#       <td id="T_7e07b_row6_col2" class="data row6 col2" >Marketing Specialist</td>
#       <td id="T_7e07b_row6_col3" class="data row6 col3" >75000</td>
#       <td id="T_7e07b_row6_col4" class="data row6 col4" >Sales</td>
#       <td id="T_7e07b_row6_col5" class="data row6 col5" >Sarah Williams</td>
#       <td id="T_7e07b_row6_col6" class="data row6 col6" >New York</td>
#       <td id="T_7e07b_row6_col7" class="data row6 col7" >101</td>
#       <td id="T_7e07b_row6_col8" class="data row6 col8" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_7e07b_level0_row7" class="row_heading level0 ro

# %%
users = pd.read_json("../Data/users.json")
users
# Out:
#   username                                           password  \
# 0   johdoe  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1   jansmi  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2   micjoh  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3   sarwil  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4   davbro  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5   emidav  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6   jacwil  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7   olimoo  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8   ethlee  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9   soptay  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2

# %%
df.insert(9, "username", 
        df["first_name"].apply(lambda name: name[:3].lower()) + 
        df["last_name"].apply(lambda name: name[:3].lower())
    )

df
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       Jane     Smith         HR Coordinator   60000  Human Resources
# 1      David     Brown             HR Manager   90000  Human Resources
# 2     Sophia    Taylor           HR Assistant   50000  Human Resources
# 3    Michael   Johnson      Software Engineer  110000               IT
# 4      Emily     Davis  IT Support Specialist   55000               IT
# 5       John       Doe         Sales Director  120000            Sales
# 6      Sarah  Williams   Marketing Specialist   75000            Sales
# 7      Jacob    Wilson   Sales Representative   80000            Sales
# 8     Olivia     Moore      Marketing Manager  100000            Sales
# 9      Ethan       Lee      Financial Analyst   85000            Sales
#
#    department_head       location  office_number   budget username
# 0      David Brown        Chicago            202   800000   jansmi
# 1      David Brown        Chicago            202   800000   davbro
# 2      David Brown        Chicago            202   800000   soptay
# 3  Michael Johnson  San Francisco            303  1200000   micjoh
# 4  Michael Johnson  San Francisco            303  1200000   emidav
# 5   Sarah Williams       New York            101  1000000   johdoe
# 6   Sarah Williams       New York            101  1000000   sarwil
# 7   Sarah Williams       New York            101  1000000   jacwil
# 8   Sarah Williams       New York            101  1000000   olimoo
# 9   Sarah Williams       New York            101  1000000   ethlee

# %%
nowrap_display(df.merge(users, on="username", how="left"))
# Out:
# <style type="text/css">
# #T_7528c th {
#   text-align: left;
# }
# #T_7528c_row0_col0, #T_7528c_row0_col1, #T_7528c_row0_col2, #T_7528c_row0_col3, #T_7528c_row0_col4, #T_7528c_row0_col5, #T_7528c_row0_col6, #T_7528c_row0_col7, #T_7528c_row0_col8, #T_7528c_row0_col9, #T_7528c_row0_col10, #T_7528c_row0_col11, #T_7528c_row0_col12, #T_7528c_row0_col13, #T_7528c_row1_col0, #T_7528c_row1_col1, #T_7528c_row1_col2, #T_7528c_row1_col3, #T_7528c_row1_col4, #T_7528c_row1_col5, #T_7528c_row1_col6, #T_7528c_row1_col7, #T_7528c_row1_col8, #T_7528c_row1_col9, #T_7528c_row1_col10, #T_7528c_row1_col11, #T_7528c_row1_col12, #T_7528c_row1_col13, #T_7528c_row2_col0, #T_7528c_row2_col1, #T_7528c_row2_col2, #T_7528c_row2_col3, #T_7528c_row2_col4, #T_7528c_row2_col5, #T_7528c_row2_col6, #T_7528c_row2_col7, #T_7528c_row2_col8, #T_7528c_row2_col9, #T_7528c_row2_col10, #T_7528c_row2_col11, #T_7528c_row2_col12, #T_7528c_row2_col13, #T_7528c_row3_col0, #T_7528c_row3_col1, #T_7528c_row3_col2, #T_7528c_row3_col3, #T_7528c_row3_col4, #T_7528c_row3_col5, #T_7528c_row3_col6, #T_7528c_row3_col7, #T_7528c_row3_col8, #T_7528c_row3_col9, #T_7528c_row3_col10, #T_7528c_row3_col11, #T_7528c_row3_col12, #T_7528c_row3_col13, #T_7528c_row4_col0, #T_7528c_row4_col1, #T_7528c_row4_col2, #T_7528c_row4_col3, #T_7528c_row4_col4, #T_7528c_row4_col5, #T_7528c_row4_col6, #T_7528c_row4_col7, #T_7528c_row4_col8, #T_7528c_row4_col9, #T_7528c_row4_col10, #T_7528c_row4_col11, #T_7528c_row4_col12, #T_7528c_row4_col13, #T_7528c_row5_col0, #T_7528c_row5_col1, #T_7528c_row5_col2, #T_7528c_row5_col3, #T_7528c_row5_col4, #T_7528c_row5_col5, #T_7528c_row5_col6, #T_7528c_row5_col7, #T_7528c_row5_col8, #T_7528c_row5_col9, #T_7528c_row5_col10, #T_7528c_row5_col11, #T_7528c_row5_col12, #T_7528c_row5_col13, #T_7528c_row6_col0, #T_7528c_row6_col1, #T_7528c_row6_col2, #T_7528c_row6_col3, #T_7528c_row6_col4, #T_7528c_row6_col5, #T_7528c_row6_col6, #T_7528c_row6_col7, #T_7528c_row6_col8, #T_7528c_row6_col9, #T_7528c_row6_col10, #T_7528c_row6_col11, #T_7528c_row6_col12, #T_7528c_row6_col13, #T_7528c_row7_col0, #T_7528c_row7_col1, #T_7528c_row7_col2, #T_7528c_row7_col3, #T_7528c_row7_col4, #T_7528c_row7_col5, #T_7528c_row7_col6, #T_7528c_row7_col7, #T_7528c_row7_col8, #T_7528c_row7_col9, #T_7528c_row7_col10, #T_7528c_row7_col11, #T_7528c_row7_col12, #T_7528c_row7_col13, #T_7528c_row8_col0, #T_7528c_row8_col1, #T_7528c_row8_col2, #T_7528c_row8_col3, #T_7528c_row8_col4, #T_7528c_row8_col5, #T_7528c_row8_col6, #T_7528c_row8_col7, #T_7528c_row8_col8, #T_7528c_row8_col9, #T_7528c_row8_col10, #T_7528c_row8_col11, #T_7528c_row8_col12, #T_7528c_row8_col13, #T_7528c_row9_col0, #T_7528c_row9_col1, #T_7528c_row9_col2, #T_7528c_row9_col3, #T_7528c_row9_col4, #T_7528c_row9_col5, #T_7528c_row9_col6, #T_7528c_row9_col7, #T_7528c_row9_col8, #T_7528c_row9_col9, #T_7528c_row9_col10, #T_7528c_row9_col11, #T_7528c_row9_col12, #T_7528c_row9_col13 {
#   font-size: 12pt;
#   text-align: left;
#   white-space: nowrap;
# }
# </style>
# <table id="T_7528c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7528c_level0_col0" class="col_heading level0 col0" >first_name</th>
#       <th id="T_7528c_level0_col1" class="col_heading level0 col1" >last_name</th>
#       <th id="T_7528c_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_7528c_level0_col3" class="col_heading level0 col3" >salary</th>
#       <th id="T_7528c_level0_col4" class="col_heading level0 col4" >department</th>
#       <th id="T_7528c_level0_col5" class="col_heading level0 col5" >department_head</th>
#       <th id="T_7528c_level0_col6" class="col_heading level0 col6" >location</th>
#       <th id="T_7528c_level0_col7" class="col_heading level0 col7" >office_number</th>
#       <th id="T_7528c_level0_col8" class="col_heading level0 col8" >budget</th>
#       <th id="T_7528c_level0_col9" class="col_heading level0 col9" >username</th>
#       <th id="T_7528c_level0_col10" class="col_heading level0 col10" >password</th>
#       <th id="T_7528c_level0_col11" class="col_heading level0 col11" >email</th>
#       <th id="T_7528c_level0_col12" class="col_heading level0 col12" >phone</th>
#       <th id="T_7528c_level0_col13" class="col_heading level0 col13" >host</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7528c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7528c_row0_col0" class="data row0 col0" >Jane</td>
#       <td id="T_7528c_row0_col1" class="data row0 col1" >Smith</td>
#       <td id="T_7528c_row0_col2" class="data row0 col2" >HR Coordinator</td>
#       <td id="T_7528c_row0_col3" class="data row0 col3" >60000</td>
#       <td id="T_7528c_row0_col4" class="data row0 col4" >Human Resources</td>
#       <td id="T_7528c_row0_col5" class="data row0 col5" >David Brown</td>
#       <td id="T_7528c_row0_col6" class="data row0 col6" >Chicago</td>
#       <td id="T_7528c_row0_col7" class="data row0 col7" >202</td>
#       <td id="T_7528c_row0_col8" class="data row0 col8" >800000</td>
#       <td id="T_7528c_row0_col9" class="data row0 col9" >jansmi</td>
#       <td id="T_7528c_row0_col10" class="data row0 col10" >a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61ed6a3f5b58d10b197a</td>
#       <td id="T_7528c_row0_col11" class="data row0 col11" >jane.smith@mockcompany.com</td>
#       <td id="T_7528c_row0_col12" class="data row0 col12" >(312) 623-3364</td>
#       <td id="T_7528c_row0_col13" class="data row0 col13" >192.168.1.2</td>
#     </tr>
#     <tr>
#       <th id="T_7528c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7528c_row1_col0" class="data row1 col0" >David</td>
#       <td id="T_7528c_row1_col1" class="data row1 col1" >Brown</td>
#       <td id="T_7528c_row1_col2" class="data row1 col2" >HR Manager</td>
#       <td id="T_7528c_row1_col3" class="data row1 col3" >90000</td>
#       <td id="T_7528c_row1_col4" class="data row1 col4" >Human Resources</td>
#       <td id="T_7528c_row1_col5" class="data row1 col5" >David Brown</td>
#       <td id="T_7528c_row1_col6" class="data row1 col6" >Chicago</td>
#       <td id="T_7528c_row1_col7" class="data row1 col7" >202</td>
#       <td id="T_7528c_row1_col8" class="data row1 col8" >800000</td>
#       <td id="T_7528c_row1_col9" class="data row1 col9" >davbro</td>
#       <td id="T_7528c_row1_col10" class="data row1 col10" >1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4a4d2c6c5f5f3a7c5f5</td>
#       <td id="T_7528c_row1_col11" class="data row1 col11" >david.brown@mockcompany.com</td>
#       <td id="T_7528c_row1_col12" class="data row1 col12" >(312) 709-8933</td>
#       <td id="T_7528c_row1_col13" class="data row1 col13" >192.168.1.2</td>
#     </tr>
#     <tr>
#       <th id="T_7528c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7528c_row2_col0" class="data row2 col0" >Sophia</td>
#       <td id="T_7528c_row2_col1" class="data row2 col1" >Taylor</td>
#       <td id="T_7528c_row2_col2" class="data row2 col2" >HR Assistant</td>
#       <td id="T_7528c_row2_col3" class="data row2 col3" >50000</td>
#       <td id="T_7528c_row2_col4" class="data row2 col4" >Human Resources</td>
#       <td id="T_7528c_row2_col5" class="data row2 col5" >David Brown</td>
#       <td id="T_7528c_row2_col6" class="data row2 col6" >Chicago</td>
#       <td id="T_7528c_row2_col7" class="data row2 col7" >202</td>
#       <td id="T_7528c_row2_col8" class="data row2 col8" >800000</td>
#       <td id="T_7528c_row2_col9" class="data row2 col9" >soptay</td>
#       <td id="T_7528c_row2_col10" class="data row2 col10" >a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439ebd0c24b1714de4d75f4</td>
#       <td id="T_7528c_row2_col11" class="data row2 col11" >sophia.taylor@mockcompany.com</td>
#       <td id="T_7528c_row2_col12" class="data row2 col12" >(312) 826-6711</td>
#       <td id="T_7528c_row2_col13" class="data row2 col13" >192.168.1.2</td>
#     </tr>
#     <tr>
#       <th id="T_7528c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7528c_row3_col0" class="data row3 col0" >Michael</td>
#       <td id="T_7528c_row3_col1" class="data row3 col1" >Johnson</td>

# %%
new_df = df.copy()

# %%
new_df.groupby(["department", "department_head", "location", "office_number", "budget"])["salary"].mean()
# Out:
# department       department_head  location       office_number  budget
# Human Resources  David Brown      Chicago        202            800000     66666.666667
# IT               Michael Johnson  San Francisco  303            1200000    82500.000000
# Sales            Sarah Williams   New York       101            1000000    92000.000000
# Name: salary, dtype: float64
