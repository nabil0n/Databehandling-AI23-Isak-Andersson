# %% [markdown]
# # Dataframes från filer
#
# - pandas (pd) kan hantera data från många filtyper. typ excel! förutom de vanliga också då såklart (csv, json osv)
# - excel behöver biblioteket openpyxl
#
# - se längre ner för smidiga sätt att hitta missad data osv

# %%
import pandas as pd
import seaborn as sns

pokemons = pd.read_csv("../data/datapoints.csv")

pokemons.head(10)
# Out:
#    (width (cm)   height (cm)   label (0-pichu   1-pikachu))
# 0    21.959384     31.239567                0           NaN
# 1    23.635916     36.468215                1           NaN
# 2    17.714056     31.441704                0           NaN
# 3    21.780200     33.213398                1           NaN
# 4    25.206306     36.558816                1           NaN
# 5    19.332572     32.253256                0           NaN
# 6    24.736457     35.332912                1           NaN
# 7    23.792576     38.103728                1           NaN
# 8    24.557613     36.731444                1           NaN
# 9    20.191281     35.069669                0           NaN

# %%
salaries = pd.read_csv("../data/salaries.csv")
salaries
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT             Data Scientist
# 1          2023               SE              FT             Data Scientist
# 2          2023               SE              FT  Machine Learning Engineer
# 3          2023               SE              FT  Machine Learning Engineer
# 4          2023               SE              FT                ML Engineer
# ...         ...              ...             ...                        ...
# 8108       2020               SE              FT             Data Scientist
# 8109       2021               MI              FT   Principal Data Scientist
# 8110       2020               EN              FT             Data Scientist
# 8111       2020               EN              CT      Business Data Analyst
# 8112       2021               SE              FT       Data Science Manager
#
# ...

# %%
salaries.head(10)
salaries.tail(10)
salaries.sample(10)
pd.set_option('display.max_rows', 20)
rows, columns = salaries.shape
print(f"Salaries has {rows} rows and {columns} columns")
# Out:
# Salaries has 8113 rows and 11 columns

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8113 entries, 0 to 8112
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           8113 non-null   int64
#  1   experience_level    8113 non-null   object
#  2   employment_type     8113 non-null   object
#  3   job_title           8113 non-null   object
#  4   salary              8113 non-null   int64
#  5   salary_currency     8113 non-null   object
#  6   salary_in_usd       8113 non-null   int64
#  7   employee_residence  8113 non-null   object
#  8   remote_ratio        8113 non-null   int64
#  9   company_location    8113 non-null   object
#  10  company_size        8113 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 697.3+ KB

# %%
# sns.relplot(data=salaries, x="salary_in_usd", y="company_size", hue="job_title")

# %% [markdown]
# ### Kopiera dataframes till ctrl+c

# %%
salaries.to_clipboard()

# %% [markdown]
# ### Ändra filtyp
#
# - Finns olika sätt att spara. Kolla doc och Fredriks genomgång

# %%
sal_json = salaries.to_json(orient="records")
# salaries.to_json("../data/salaries.json")

# %%
# salaries.to_dict(orient="records")
