# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
boxoffice = pd.read_html("https://en.wikipedia.org/wiki/List_of_Pixar_films", header=1, match="Box office gross")[0]

# %%
boxoffice.drop(columns="Ref.", inplace=True)

# %%
boxoffice.replace(to_replace="[$]", value="", regex=True, inplace=True)

# %%
boxoffice.replace(to_replace=",", value="", regex=True, inplace=True)

# %%
boxoffice2 = boxoffice.copy()
boxoffice2
# Out:
#     Year                 Film           Budget U.S. and Canada  \
# 0   1995            Toy Story       30 million       192523233
# 1   1998         A Bug's Life      120 million       162798565
# 2   1999          Toy Story 2       90 million       245852179
# 3   2001        Monsters Inc.      115 million       289916256
# 4   2003         Finding Nemo       94 million       339714978
# 5   2004      The Incredibles       92 million       261441092
# 6   2006                 Cars      120 million       244082982
# 7   2007          Ratatouille      150 million       206445654
# 8   2008               WALL-E      180 million       223808164
# 9   2009                   Up      175 million       293004164
# 10  2010          Toy Story 3      200 million       415004880
# 11  2011               Cars 2      200 million       191452396
# 12  2012                Brave      185 million       237283207
# 13  2013  Monsters University      200 million       268492764
# ...

# %%
boxoffice2.replace(to_replace="\xa0million", value="000000", regex=True, inplace=True)

# %%
boxoffice2
# Out:
#     Year                 Film         Budget Other territories   Worldwide
# 0   1995            Toy Story       30000000         172747718   365270951
# 1   1998         A Bug's Life      120000000         200460294   363258859
# 2   1999          Toy Story 2       90000000         265506097   511358276
# 3   2001        Monsters Inc.      115000000         342400393   632316649
# 4   2003         Finding Nemo       94000000         531300000   871014978
# 5   2004      The Incredibles       92000000         370165621   631606713
# 6   2006                 Cars      120000000         217900167   461983149
# 7   2007          Ratatouille      150000000         417280431   623726085
# 8   2008               WALL-E      180000000         297503696   521311860
# 9   2009                   Up      175000000         442094918   735099082
# 10  2010          Toy Story 3      200000000         651964823  1066969703
# ...

# %%
boxoffice2.drop(columns="U.S. and Canada", inplace=True)

# %%
boxoffice2.drop(columns="Other territories", inplace=True)

# %%
boxoffice2
# Out:
#     Year                 Film         Budget   Worldwide
# 0   1995            Toy Story       30000000   365270951
# 1   1998         A Bug's Life      120000000   363258859
# 2   1999          Toy Story 2       90000000   511358276
# 3   2001        Monsters Inc.      115000000   632316649
# 4   2003         Finding Nemo       94000000   871014978
# 5   2004      The Incredibles       92000000   631606713
# 6   2006                 Cars      120000000   461983149
# 7   2007          Ratatouille      150000000   623726085
# 8   2008               WALL-E      180000000   521311860
# 9   2009                   Up      175000000   735099082
# 10  2010          Toy Story 3      200000000  1066969703
# 11  2011               Cars 2      200000000   559852396
# 12  2012                Brave      185000000   538983207
# 13  2013  Monsters University      200000000   743559607
# 14  2015           Inside Out      175000000   857611174
# ...

# %%
boxoffice2.replace(to_replace="—", value=np.NaN, inplace=True)

# %%
boxoffice2["Worldwide"].astype("int64")
boxoffice2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       27 non-null     int64
#  1   Film       27 non-null     object
#  2   Budget     26 non-null     object
#  3   Worldwide  27 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 996.0+ bytes

# %%
boxoffice2["Worldwide"] = boxoffice2["Worldwide"].astype("int64")
boxoffice2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       27 non-null     int64
#  1   Film       27 non-null     object
#  2   Budget     26 non-null     object
#  3   Worldwide  27 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 996.0+ bytes

# %%
boxoffice2["Budget"] = boxoffice2["Budget"].astype("int64") if 
boxoffice2.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\KODA\ITHS\Databehandling-AI23-Isak-Andersson\Genomgångar\12_Read_html.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/KODA/ITHS/Databehandling-AI23-Isak-Andersson/Genomg%C3%A5ngar/12_Read_html.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> boxoffice2["Budget"] = boxoffice2["Budget"].astype("int64")
#       <a href='vscode-notebook-cell:/c%3A/KODA/ITHS/Databehandling-AI23-Isak-Andersson/Genomg%C3%A5ngar/12_Read_html.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> boxoffice2.info()
#
# File c:\Users\isaka\.virtualenvs\Databehandling-AI23-Isak-Andersson-guo_hG4P\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# ...
